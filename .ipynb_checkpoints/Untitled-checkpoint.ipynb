# %%
import requests

# %%
a = requests.get('http://172.20.122.101:8000/track/api/62d938945e738e48086cfc9e')

# %%
a
# Out:
# <Response [200]>

# %%
c = a.json()

# %%
b = a.text

# %%
b.find("tracking_data")
# Out:
# 61

# %%
b.find('Temperature')
# Out:
# 1247

# %%
b[1247:]
# Out:
# 'Temperature, Humidity Data","timestamp":1658403140000,"data":"Time = 21/07/2022 05:01:00 PM\\nTemp = 32°C\\nHumidity = 71% \\n\\nTime = 21/07/2022 05:02:00 PM\\nTemp = 32°C\\nHumidity = 71% "},{"Event":"Reached delhi, dl","timestamp":1661407010364,"company_name":"gatiman express","address":"karol bagh, new delhi","city":"delhi","code":"dl","pincode":"201001","notes":"Damaged in transit"},{"Event":"Departed delhi, dl","timestamp":1661407132822,"company_name":"gatiman express","address":"karol bagh, new delhi","city":"delhi","code":"dl","pincode":"201001","notes":"Packaging repaired"},"{temp :  37C}",{"Event":"Hardware Data","timestamp":1661433822932,"data":"{temp :  37C}"},{"Event":"Hardware Data","timestamp":1661451883380,"data":"{temp :  37C}"},{"Event":"Hardware Data","timestamp":1661452048050,"data":"{temp :  37C}"},{"Event":"Hardware Data","timestamp":1661452075083,"data":"{temp :  37C}"},{"Event":"Hardware Data","timestamp":1661452104455,"data":"{temp :  37C}"},{"Event":"Hardware Data","timestamp":1661459839764,"data":"{temp :  37C}"},{"Event":"Hardware Data","timestamp":1661461561660,"data":"{temp :  37C}"},{"Event":"Hardware Data","timestamp":1661482463740,"data":1548},{"Event":"Hardware Data","timestamp":1661487571056,"data":"hello"},{"Event":"Hardware Data","timestamp":1661487573045,"data":"hello"},{"Event":"Hardware Data","timestamp":1661487582829,"data":"hello"},{"Event":"Hardware Data","timestamp":1661487585240,"data":"hello"},{"Event":"Hardware Data","timestamp":1661488518905,"data":"h"},{"Event":"Hardware Data","timestamp":1661488541773,"data":"h"},{"Event":"Hardware Data","timestamp":1661488564276,"data":"h"},{"Event":"Hardware Data","timestamp":1661488586556,"data":"h"},{"Event":"Hardware Data","timestamp":1661488613753,"data":"h"},{"Event":"Hardware Data","timestamp":1661488636001,"data":"h"},{"Event":"Hardware Data","timestamp":1661488658055,"data":"h"},{"Event":"Hardware Data","timestamp":1661488680335,"data":"h"},{"Event":"Hardware Data","timestamp":1661488702556,"data":"h"},{"Event":"Hardware Data","timestamp":1661488724903,"data":"h"},{"Event":"Hardware Data","timestamp":1661488747953,"data":"h"},{"Event":"Hardware Data","timestamp":1661488770354,"data":"h"},{"Event":"Hardware Data","timestamp":1661488789540,"data":1548},{"Event":"Hardware Data","timestamp":1661488830711,"data":"h"},{"Event":"Hardware Data","timestamp":1661488870443,"data":{"timestamp":"26/08/2022 05:41:09","gps":"9.57 , 77.67","temperature":26,"humidity":58}},{"Event":"Hardware Data","timestamp":1661495107717,"data":{"timestamp":"26/08/2022 07:25:05","gps":"9.57 , 77.67","temperature":24,"humidity":56}},{"Event":"Hardware Data","timestamp":1661495115012,"data":{"timestamp":"26/08/2022 07:25:13","gps":"9.57 , 77.67","temperature":24,"humidity":56}},{"Event":"Hardware Data","timestamp":1661505462588,"data":{"timestamp":"26/08/2022 10:17:27","temperature":25,"humidity":52,"gps":"9.57 , 77.67"}},{"Event":"Hardware Data","timestamp":1661505465805,"data":{"timestamp":"26/08/2022 10:17:43","temperature":25,"humidity":52,"gps":"9.57 , 77.67"}},{"Event":"Hardware Data","timestamp":1661505510182,"data":{"timestamp":"26/08/2022 10:18:28","temperature":25,"humidity":52,"gps":"9.57 , 77.67"}},{"Event":"Hardware Data","timestamp":1661505512236,"data":{"timestamp":"26/08/2022 10:18:31","temperature":25,"humidity":53,"gps":"9.57 , 77.67"}},{"Event":"Hardware Data","timestamp":1661505715582,"data":{"timestamp":"26/08/2022 10:21:51","temperature":25,"humidity":53,"gps":"9.57 , 77.67"}},{"Event":"Hardware Data","timestamp":1661505737919,"data":{"timestamp":"26/08/2022 10:22:16","temperature":25,"humidity":53,"gps":"9.57 , 77.67"}},{"Event":"Hardware Data","timestamp":1661505744344,"data":{"timestamp":"26/08/2022 10:22:22","temperature":25,"humidity":53,"gps":"9.57 , 77.67"}},{"Event":"Hardware Data","timestamp":1661508262460,"data":{"timestamp":"26/08/2022 11:04:19","temperature":25,"humidity":54,"gps":"9.57 , 77.67"}},{"Event":"Hardware Data","timestamp" ...

# %%
c
# Out:
# {'result': 'success',
#  'data': {'id': '62d938945e738e48086cfc9e',
#   'tracking_data': [{'Event': 'Registration',
#     'timestamp': 1658402964142,
#     'name': 'mustard seeds',
#     'description': '100% Organic',
#     'producer': 'piyush rai',
#     'registered_at_pincode': '201009',
#     'weight': '100'},
#    {'Event': 'Got certification from From Nature Organic',
#     'timestamp': 1658403005000,
#     'certifier_name': 'From Nature Organic',
#     'certification_id': '13224324',
#     'remarks': 'Score : 86'},
#    {'Event': 'Farm Produce Collected',
#     'timestamp': 1658403071000,
#     'collection_center_id': '62d92fc6b51bf18a49317550',
#     'collection_center_name': 'ghaziabad collection center',
#     'transaction_amount': '1250',
#     'notes': 'good quality'},
#    {'Event': 'Hardware attached to track realtime data',
#     'timestamp': 1658403071010,
#     'collection_center_id': '62d92fc6b51bf18a49317550',
#     'collection_center_name': 'ghaziabad collection center',
#     'hardware_id': '12345'},
#    {'Event': 'Reached delhi, dl',
#     'timestamp': 1658403096000,
#     'company_name': 'gatiman express',
#     'address': 'karol bagh, new delhi',
#     'city': 'delhi',
#     'code': 'dl',
#     'pincode': '201001',
#     'notes': 'Good condition'},
#    {'Event': 'Departed delhi, dl',
#     'timestamp': 1658403135000,
#     'company_name': 'gatiman express',
#     'address': 'karol bagh, new delhi',
#     'city': 'delhi',
#     'code': 'dl',
#     'pincode': '201001',
#     'notes': 'Good condition'},
#    {'Event': 'Temperature, Humidity Data',
#     'timestamp': 1658403140000,
#     'data': 'Time = 21/07/2022 05:01:00 PM\nTemp = 32°C\nHumidity = 71% \n\nTime = 21/07/2022 05:02:00 PM\nTemp = 32°C\nHumidity = 71% '},
#    {'Event': 'Reached delhi, dl',
#     'timestamp': 1661407010364,
#     'company_name': 'gatiman express',
#     'address': 'karol bagh, new delhi',
#     'city': 'delhi',
#     'code': 'dl',
#     'pincode': '201001',
#     'notes': 'Damaged in transit'},
#    {'Event': 'Departed delhi, dl',
#     'timestamp': 1661407132822,
#     'company_name': 'gatiman express',
#     'address': 'karol bagh, new delhi',
#     'city': 'delhi',
#     'code': 'dl',
#     'pincode': '201001',
#     'notes': 'Packaging repaired'},
#    '{temp :  37C}',
#    {'Event': 'Hardware Data',
#     'timestamp': 1661433822932,
#     'data': '{temp :  37C}'},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661451883380,
#     'data': '{temp :  37C}'},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661452048050,
#     'data': '{temp :  37C}'},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661452075083,
#     'data': '{temp :  37C}'},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661452104455,
#     'data': '{temp :  37C}'},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661459839764,
#     'data': '{temp :  37C}'},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661461561660,
#     'data': '{temp :  37C}'},
#    {'Event': 'Hardware Data', 'timestamp': 1661482463740, 'data': 1548},
#    {'Event': 'Hardware Data', 'timestamp': 1661487571056, 'data': 'hello'},
#    {'Event': 'Hardware Data', 'timestamp': 1661487573045, 'data': 'hello'},
#    {'Event': 'Hardware Data', 'timestamp': 1661487582829, 'data': 'hello'},
#    {'Event': 'Hardware Data', 'timestamp': 1661487585240, 'data': 'hello'},
#    {'Event': 'Hardware Data', 'timestamp': 1661488518905, 'data': 'h'},
#    {'Event': 'Hardware Data', 'timestamp': 1661488541773, 'data': 'h'},
#    {'Event': 'Hardware Data', 'timestamp': 1661488564276, 'data': 'h'},
#    {'Event': 'Hardware Data', 'timestamp': 1661488586556, 'data': 'h'},
#    {'Event': 'Hardware Data', 'timestamp': 1661488613753, 'data': 'h'},
#    {'Event': 'Hardware Data', 'timestamp': 1661488636001, 'data': 'h'},
#    {'Event': 'Hardware Data', 'timestamp': 1661488658055, 'data': 'h'},
#    {'Event': 'Hardware Data', 'timestamp': 1661488680335, 'data': 'h'},
#    {'Event': 'Hardware Data', 'timestamp': 1661488702556, 'data': 'h'},
#    {'Event': 'Hardware Data', 'timestamp': 1661488724903, 'data': 'h'},
#    {'Event': 'Hardware Data', 'timestamp': 1661488747953, 'data': 'h'},
#    {'Event': 'Hardware Data', 'timestamp': 1661488770354, 'data': 'h'},
#    {'Event': 'Hardware Data', 'timestamp': 1661488789540, 'data': 1548},
#    {'Event': 'Hardware Data', 'timestamp': 1661488830711, 'data': 'h'},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661488870443,
#     'data': {'timestamp': '26/08/2022 05:41:09',
#      'gps': '9.57 , 77.67',
#      'temperature': 26,
#      'humidity': 58}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661495107717,
#     'data': {'timestamp': '26/08/2022 07:25:05',
#      'gps': '9.57 , 77.67',
#      'temperature': 24,
#      'humidity': 56}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661495115012,
#     'data': {'timestamp': '26/08/2022 07:25:13',
#      'gps': '9.57 , 77.67',
#      'temperature': 24,
#      'humidity': 56}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661505462588,
#     'data': {'timestamp': '26/08/2022 10:17:27',
#      'temperature': 25,
#      'humidity': 52,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661505465805,
#     'data': {'timestamp': '26/08/2022 10:17:43',
#      'temperature': 25,
#      'humidity': 52,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661505510182,
#     'data': {'timestamp': '26/08/2022 10:18:28',
#      'temperature': 25,
#      'humidity': 52,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661505512236,
#     'data': {'timestamp': '26/08/2022 10:18:31',
#      'temperature': 25,
#      'humidity': 53,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661505715582,
#     'data': {'timestamp': '26/08/2022 10:21:51',
#      'temperature': 25,
#      'humidity': 53,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661505737919,
#     'data': {'timestamp': '26/08/2022 10:22:16',
#      'temperature': 25,
#      'humidity': 53,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661505744344,
#     'data': {'timestamp': '26/08/2022 10:22:22',
#      'temperature': 25,
#      'humidity': 53,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661508262460,
#     'data': {'timestamp': '26/08/2022 11:04:19',
#      'temperature': 25,
#      'humidity': 54,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661508285760,
#     'data': {'timestamp': '26/08/2022 11:04:43',
#      'temperature': 25,
#      'humidity': 54,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661508306214,
#     'data': {'timestamp': '26/08/2022 11:05:03',
#      'temperature': 25,
#      'humidity': 54,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661508331031,
#     'data': {'timestamp': '26/08/2022 11:05:29',
#      'temperature': 25,
#      'humidity': 54,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661508353422,
#     'data': {'timestamp': '26/08/2022 11:05:52',
#      'temperature': 25,
#      'humidity': 54,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661508379289,
#     'data': {'timestamp': '26/08/2022 11:06:16',
#      'temperature': 25,
#      'humidity': 54,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661508407365,
#     'data': {'timestamp': '26/08/2022 11:06:45',
#      'temperature': 25,
#      'humidity': 54,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661508430695,
#     'data': {'timestamp': '26/08/2022 11:07:08',
#      'temperature': 25,
#      'humidity': 54,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661510402640,
#     'data': {'timestamp': '26/08/2022 11:40:00',
#      'temperature': 24,
#      'humidity': 51,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661510425956,
#     'data': {'timestamp': '26/08/2022 11:40:23',
#      'temperature': 24,
#      'humidity': 51,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661510428550,
#     'data': {'timestamp': '26/08/2022 11:40:26',
#      'temperature': 24,
#      'humidity': 51,
#      'gps': '9.57 , 77.67'}},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661533676046,
#     'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661534013761,
#     'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661534023181,
#     'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661534064851,
#     'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661534067319,
#     'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'},
#    {'Event': 'Hardware Data',
#     'timestamp': 1661535294710,
#     'data': [{'timestamp': '26/08/2022 18:34:17',
#       'temperature': 24,
#       'humidity': 54,
#       'gps': '9.57 , 77.67'},
#      {'timestamp': '26/08/2022 18:34:23',
#       'temperature': 25,
#       'humidity': 54,
#       'gps': '9.57 , 77.67'},
#      {'timestamp': '26/08/2022 18:34:31',
#       'temperature': 25,
#       'humidity': 54,
#       'gps': '9.57 , 77.67'},
#      {'timestamp': '26/08/2022 18:34:36',
#       'temperature': 25,
#       'humidity': 54,
#       'gps': '9.57 , 77.67'},
#      {'timestamp': '26/08/2022 18:34:42',
#       'temperature': 25,
#       'humidity': 54,
#       'gps': '9.57 , 77.67'},
#      {'timestamp': '26/08/2022 18:34:47',
#       'temperature': 25,
#       'humidity': 54,
#       'gps': '9.57 , 77.67'}]},
#    {'Event': 'Departed delhi, dl',
#     'timestamp': 1661537458081,
#     'company_name': 'gatiman express',
#     'address': 'karol bagh, new delhi',
#     'city': 'delhi',
#     'code': 'dl',
#     'pincode': '201001',
#     'notes': 'None'},
#    {'Event': 'Departed delhi, dl',
#     'timestamp': 1661537496465,
#     'company_name': 'gatiman express',
#     'address': 'karol bagh, new delhi',
#     'city': 'delhi',
#     'code': 'dl',
#     'pincode': '201001',
#     'notes': 'None'},
#    {'Event': 'Departed delhi, dl',
#     'timestamp': 1661543914296,
#     'company_name': 'gatiman express',
#     'address': 'karol bagh, new delhi',
#     'city': 'delhi',
#     'code': 'dl',
#     'pincode': '201001',
#     'notes': 'None'},
#    {'Event': 'Departed delhi, dl',
#     'timestamp': 1661568646589,
#     'company_name': 'gatiman express',
#     'address': 'karol bagh, new delhi',
#     'city': 'delhi',
#     'code': 'dl',
#     'pincode': '201001',
#     'notes': 'None'},
#    {'Event': 'Departed delhi, dl',
#     'timestamp': 1661568663061,
#     'company_name': 'gatiman express',
#     'address': 'karol bagh, new delhi',
#     'city': 'delhi',
#     'code': 'dl',
#     'pincode': '201001',
#     'notes': 'None'},
#    {'Event': 'Departed delhi, dl',
#     'timestamp': 1661572888724,
#     'company_name': 'gatiman express',
#     'address': 'karol bagh, new delhi',
#     'city': 'delhi',
#     'code': 'dl',
#     'pincode': '201001',
#     'notes': 'None'},
#    {'Event': 'Departed delhi, dl',
#     'timestamp': 1661573547458,
#     'company_name': 'gatiman express',
#     'address': 'karol bagh, new delhi',
#     'city': 'delhi',
#     'code': 'dl',
#     'pincode': '201001',
#     'notes': 'None'}],
#   'hardware_data': [{'timestamp': 1661540193658.111,
#     'temperature': 24,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540196185.414,
#     'temperature': 24,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540199692.975,
#     'temperature': 24,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540202220.318,
#     'temperature': 25,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540205704.98,
#     'temperature': 25,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540208232.434,
#     'temperature': 25,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540211686.279,
#     'temperature': 25,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540214213.734,
#     'temperature': 25,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540220253.984,
#     'temperature': 25,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540222781.406,
#     'temperature': 25,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540228683.5688,
#     'temperature': 25,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540233742.107,
#     'temperature': 25,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540239712.036,
#     'temperature': 25,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540244766.707,
#     'temperature': 25,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540366086.175,
#     'temperature': 24,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661540368613.6401,
#     'temperature': 25,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661541162430.678,
#     'temperature': 25,
#     'humidity': 62,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661541169594.6938,
#     'temperature': 25,
#     'humidity': 62,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661541174121.1892,
#     'temperature': 25,
#     'humidity': 62,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661541178751.099,
#     'temperature': 25,
#     'humidity': 62,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661541186131.4548,
#     'temperature': 25,
#     'humidity': 62,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661543286420.581,
#     'temperature': 25,
#     'humidity': 66,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661543291048.561,
#     'temperature': 25,
#     'humidity': 66,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661543298060.366,
#     'temperature': 25,
#     'humidity': 67,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661543338796.261,
#     'temperature': 25,
#     'humidity': 66,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661543345935.393,
#     'temperature': 25,
#     'humidity': 67,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661543555269.719,
#     'temperature': 25,
#     'humidity': 68,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661543558822.4558,
#     'temperature': 25,
#     'humidity': 68,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661543771758.6611,
#     'temperature': 25,
#     'humidity': 66,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661543775344.5662,
#     'temperature': 25,
#     'humidity': 67,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661543833533.579,
#     'temperature': 25,
#     'humidity': 65,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661543973265.282,
#     'temperature': 25,
#     'humidity': 64,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661544244027.3782,
#     'temperature': 25,
#     'humidity': 63,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661544329698.39,
#     'temperature': 25,
#     'humidity': 62,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661544454575.638,
#     'temperature': 25,
#     'humidity': 61,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': 1661545634872.7888,
#     'temperature': 26,
#     'humidity': 71,
#     'gps': '9.57 , 77.67'}]}}

# %%
d = c['data']

# %%
l = d['tracking_data']

# %%
# for i in range(len(l)-1):
#     if 'data' in l[i].keys():
#         print("yes")
# # if 'data' in l[50].keys():
# #     print("yes")
for i in range(len(l)):
    if(type(l[i]) != 'dict'):
        print(l[i])
# Out:
# {'Event': 'Registration', 'timestamp': 1658402964142, 'name': 'mustard seeds', 'description': '100% Organic', 'producer': 'piyush rai', 'registered_at_pincode': '201009', 'weight': '100'}
# {'Event': 'Got certification from From Nature Organic', 'timestamp': 1658403005000, 'certifier_name': 'From Nature Organic', 'certification_id': '13224324', 'remarks': 'Score : 86'}
# {'Event': 'Farm Produce Collected', 'timestamp': 1658403071000, 'collection_center_id': '62d92fc6b51bf18a49317550', 'collection_center_name': 'ghaziabad collection center', 'transaction_amount': '1250', 'notes': 'good quality'}
# {'Event': 'Hardware attached to track realtime data', 'timestamp': 1658403071010, 'collection_center_id': '62d92fc6b51bf18a49317550', 'collection_center_name': 'ghaziabad collection center', 'hardware_id': '12345'}
# {'Event': 'Reached delhi, dl', 'timestamp': 1658403096000, 'company_name': 'gatiman express', 'address': 'karol bagh, new delhi', 'city': 'delhi', 'code': 'dl', 'pincode': '201001', 'notes': 'Good condition'}
# {'Event': 'Departed delhi, dl', 'timestamp': 1658403135000, 'company_name': 'gatiman express', 'address': 'karol bagh, new delhi', 'city': 'delhi', 'code': 'dl', 'pincode': '201001', 'notes': 'Good condition'}
# {'Event': 'Temperature, Humidity Data', 'timestamp': 1658403140000, 'data': 'Time = 21/07/2022 05:01:00 PM\nTemp = 32°C\nHumidity = 71% \n\nTime = 21/07/2022 05:02:00 PM\nTemp = 32°C\nHumidity = 71% '}
# {'Event': 'Reached delhi, dl', 'timestamp': 1661407010364, 'company_name': 'gatiman express', 'address': 'karol bagh, new delhi', 'city': 'delhi', 'code': 'dl', 'pincode': '201001', 'notes': 'Damaged in transit'}
# {'Event': 'Departed delhi, dl', 'timestamp': 1661407132822, 'company_name': 'gatiman express', 'address': 'karol bagh, new delhi', 'city': 'delhi', 'code': 'dl', 'pincode': '201001', 'notes': 'Packaging repaired'}
# {temp :  37C}
# {'Event': 'Hardware Data', 'timestamp': 1661433822932, 'data': '{temp :  37C}'}
# {'Event': 'Hardware Data', 'timestamp': 1661451883380, 'data': '{temp :  37C}'}
# {'Event': 'Hardware Data', 'timestamp': 1661452048050, 'data': '{temp :  37C}'}
# {'Event': 'Hardware Data', 'timestamp': 1661452075083, 'data': '{temp :  37C}'}
# {'Event': 'Hardware Data', 'timestamp': 1661452104455, 'data': '{temp :  37C}'}
# {'Event': 'Hardware Data', 'timestamp': 1661459839764, 'data': '{temp :  37C}'}
# {'Event': 'Hardware Data', 'timestamp': 1661461561660, 'data': '{temp :  37C}'}
# {'Event': 'Hardware Data', 'timestamp': 1661482463740, 'data': 1548}
# {'Event': 'Hardware Data', 'timestamp': 1661487571056, 'data': 'hello'}
# {'Event': 'Hardware Data', 'timestamp': 1661487573045, 'data': 'hello'}
# {'Event': 'Hardware Data', 'timestamp': 1661487582829, 'data': 'hello'}
# {'Event': 'Hardware Data', 'timestamp': 1661487585240, 'data': 'hello'}
# {'Event': 'Hardware Data', 'timestamp': 1661488518905, 'data': 'h'}
# {'Event': 'Hardware Data', 'timestamp': 1661488541773, 'data': 'h'}
# {'Event': 'Hardware Data', 'timestamp': 1661488564276, 'data': 'h'}
# {'Event': 'Hardware Data', 'timestamp': 1661488586556, 'data': 'h'}
# {'Event': 'Hardware Data', 'timestamp': 1661488613753, 'data': 'h'}
# {'Event': 'Hardware Data', 'timestamp': 1661488636001, 'data': 'h'}
# {'Event': 'Hardware Data', 'timestamp': 1661488658055, 'data': 'h'}
# {'Event': 'Hardware Data', 'timestamp': 1661488680335, 'data': 'h'}
# {'Event': 'Hardware Data', 'timestamp': 1661488702556, 'data': 'h'}
# {'Event': 'Hardware Data', 'timestamp': 1661488724903, 'data': 'h'}
# {'Event': 'Hardware Data', 'timestamp': 1661488747953, 'data': 'h'}
# {'Event': 'Hardware Data', 'timestamp': 1661488770354, 'data': 'h'}
# {'Event': 'Hardware Data', 'timestamp': 1661488789540, 'data': 1548}
# {'Event': 'Hardware Data', 'timestamp': 1661488830711, 'data': 'h'}
# {'Event': 'Hardware Data', 'timestamp': 1661488870443, 'data': {'timestamp': '26/08/2022 05:41:09', 'gps': '9.57 , 77.67', 'temperature': 26, 'humidity': 58}}
# {'Event': 'Hardware Data', 'timestamp': 1661495107717, 'data': {'timestamp': '26/08/2022 07:25:05', 'gps': '9.57 , 77.67', 'temperature': 24, 'humidity': 56}}
# {'Event': 'Hardware Data', 'timestamp': 1661495115012, 'data': {'timestamp': '26/08/2022 07:25:13', 'gps': '9.57 , 77.67', 'temperature': 24, 'humidity': 56}}
# {'Event': 'Hardware Data', 'timestamp': 1661505462588, 'data': {'timestamp': '26/08/2022 10:17:27', 'temperature': 25, 'humidity': 52, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661505465805, 'data': {'timestamp': '26/08/2022 10:17:43', 'temperature': 25, 'humidity': 52, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661505510182, 'data': {'timestamp': '26/08/2022 10:18:28', 'temperature': 25, 'humidity': 52, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661505512236, 'data': {'timestamp': '26/08/2022 10:18:31', 'temperature': 25, 'humidity': 53, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661505715582, 'data': {'timestamp': '26/08/2022 10:21:51', 'temperature': 25, 'humidity': 53, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661505737919, 'data': {'timestamp': '26/08/2022 10:22:16', 'temperature': 25, 'humidity': 53, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661505744344, 'data': {'timestamp': '26/08/2022 10:22:22', 'temperature': 25, 'humidity': 53, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661508262460, 'data': {'timestamp': '26/08/2022 11:04:19', 'temperature': 25, 'humidity': 54, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661508285760, 'data': {'timestamp': '26/08/2022 11:04:43', 'temperature': 25, 'humidity': 54, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661508306214, 'data': {'timestamp': '26/08/2022 11:05:03', 'temperature': 25, 'humidity': 54, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661508331031, 'data': {'timestamp': '26/08/2022 11:05:29', 'temperature': 25, 'humidity': 54, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661508353422, 'data': {'timestamp': '26/08/2022 11:05:52', 'temperature': 25, 'humidity': 54, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661508379289, 'data': {'timestamp': '26/08/2022 11:06:16', 'temperature': 25, 'humidity': 54, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661508407365, 'data': {'timestamp': '26/08/2022 11:06:45', 'temperature': 25, 'humidity': 54, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661508430695, 'data': {'timestamp': '26/08/2022 11:07:08', 'temperature': 25, 'humidity': 54, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661510402640, 'data': {'timestamp': '26/08/2022 11:40:00', 'temperature': 24, 'humidity': 51, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661510425956, 'data': {'timestamp': '26/08/2022 11:40:23', 'temperature': 24, 'humidity': 51, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661510428550, 'data': {'timestamp': '26/08/2022 11:40:26', 'temperature': 24, 'humidity': 51, 'gps': '9.57 , 77.67'}}
# {'Event': 'Hardware Data', 'timestamp': 1661533676046, 'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'}
# {'Event': 'Hardware Data', 'timestamp': 1661534013761, 'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'}
# {'Event': 'Hardware Data', 'timestamp': 1661534023181, 'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'}
# {'Event': 'Hardware Data', 'timestamp': 1661534064851, 'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'}
# {'Event': 'Hardware Data', 'timestamp': 1661534067319, 'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'}
# {'Event': 'Hardware Data', 'timestamp': 1661535294710, 'data': [{'timestamp': '26/08/2022 18:34:17', 'temperature': 24, 'humidity': 54, 'gps': '9.57 , 77.67'}, {'timestamp': '26/08/2022 18:34:23', 'temperature': 25, 'humidity': 54, 'gps': '9.57 , 77.67'}, {'timestamp': '26/08/2022 18:34:31', 'temperature': 25, 'humidity': 54, 'gps': '9.57 , 77.67'}, {'timestamp': '26/08/2022 18:34:36', 'temperature': 25, 'humidity': 54, 'gps': '9.57 , 77.67'}, {'timestamp': '26/08/2022 18:34:42', 'temperature': 25, 'humidity': 54, 'gps': '9.57 , 77.67'}, {'timestamp': '26/08/2022 18:34:47', 'temperature': 25, 'humidity': 54, 'gps': '9.57 , 77.67'}]}
# {'Event': 'Departed delhi, dl', 'timestamp': 1661537458081, 'company_name': 'gatiman express', 'address': 'karol bagh, new delhi', 'city': 'delhi', 'code': 'dl', 'pincode': '201001', 'notes': 'None'}
# {'Event': 'Departed delhi, dl', 'timestamp': 1661537496465, 'company_name': 'gatiman express', 'address': 'karol bagh, new delhi', 'city': 'delhi', 'code': 'dl', 'pincode': '201001', 'notes': 'None'}
# {'Event': 'Departed delhi, dl', 'timestamp': 1661543914296, 'company_name': 'gatiman express', 'address': 'karol bagh, new delhi', 'city': 'delhi', 'code': 'dl', 'pincode': '201001', 'notes': 'None'}
# {'Event': 'Departed delhi, dl', 'timestamp': 1661568646589, 'company_name': 'gatiman express', 'address': 'karol bagh, new delhi', 'city': 'delhi', 'code': 'dl', 'pincode': '201001', 'notes': 'None'}
# {'Event': 'Departed delhi, dl', 'timestamp': 1661568663061, 'company_name': 'gatiman express', 'address': 'karol bagh, new delhi', 'city': 'delhi', 'code': 'dl', 'pincode': '201001', 'notes': 'None'}
# {'Event': 'Departed delhi, dl', 'timestamp': 1661572888724, 'company_name': 'gatiman express', 'address': 'karol bagh, new delhi', 'city': 'delhi', 'code': 'dl', 'pincode': '201001', 'notes': 'None'}
# {'Event': 'Departed delhi, dl', 'timestamp': 1661573547458, 'company_name': 'gatiman express', 'address': 'karol bagh, new delhi', 'city': 'delhi', 'code': 'dl', 'pincode': '201001', 'notes': 'None'}

# %%
d2
# Out:
# {'Event': 'Hardware Data',
#  'timestamp': 1661508353422,
#  'data': {'timestamp': '26/08/2022 11:05:52',
#   'temperature': 25,
#   'humidity': 54,
#   'gps': '9.57 , 77.67'}}

# %%
d3 = d2['data']

# %%
d3
# Out:
# {'timestamp': '26/08/2022 11:05:52',
#  'temperature': 25,
#  'humidity': 54,
#  'gps': '9.57 , 77.67'}

# %%
d3['temperature']
# Out:
# 25

# %%
d3['humidity']
# Out:
# 54

# %%
for i in l:
        print(type(i))
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'str'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>

# %%
a = []
for i in range(len(l)):
    if type(l[i]) == dict:
        a.append(dict(l[i]))

# %%
for i in a:
    print(type(i))
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>

# %%
a
# Out:
# [{'Event': 'Registration',
#   'timestamp': 1658402964142,
#   'name': 'mustard seeds',
#   'description': '100% Organic',
#   'producer': 'piyush rai',
#   'registered_at_pincode': '201009',
#   'weight': '100'},
#  {'Event': 'Got certification from From Nature Organic',
#   'timestamp': 1658403005000,
#   'certifier_name': 'From Nature Organic',
#   'certification_id': '13224324',
#   'remarks': 'Score : 86'},
#  {'Event': 'Farm Produce Collected',
#   'timestamp': 1658403071000,
#   'collection_center_id': '62d92fc6b51bf18a49317550',
#   'collection_center_name': 'ghaziabad collection center',
#   'transaction_amount': '1250',
#   'notes': 'good quality'},
#  {'Event': 'Hardware attached to track realtime data',
#   'timestamp': 1658403071010,
#   'collection_center_id': '62d92fc6b51bf18a49317550',
#   'collection_center_name': 'ghaziabad collection center',
#   'hardware_id': '12345'},
#  {'Event': 'Reached delhi, dl',
#   'timestamp': 1658403096000,
#   'company_name': 'gatiman express',
#   'address': 'karol bagh, new delhi',
#   'city': 'delhi',
#   'code': 'dl',
#   'pincode': '201001',
#   'notes': 'Good condition'},
#  {'Event': 'Departed delhi, dl',
#   'timestamp': 1658403135000,
#   'company_name': 'gatiman express',
#   'address': 'karol bagh, new delhi',
#   'city': 'delhi',
#   'code': 'dl',
#   'pincode': '201001',
#   'notes': 'Good condition'},
#  {'Event': 'Temperature, Humidity Data',
#   'timestamp': 1658403140000,
#   'data': 'Time = 21/07/2022 05:01:00 PM\nTemp = 32°C\nHumidity = 71% \n\nTime = 21/07/2022 05:02:00 PM\nTemp = 32°C\nHumidity = 71% '},
#  {'Event': 'Reached delhi, dl',
#   'timestamp': 1661407010364,
#   'company_name': 'gatiman express',
#   'address': 'karol bagh, new delhi',
#   'city': 'delhi',
#   'code': 'dl',
#   'pincode': '201001',
#   'notes': 'Damaged in transit'},
#  {'Event': 'Departed delhi, dl',
#   'timestamp': 1661407132822,
#   'company_name': 'gatiman express',
#   'address': 'karol bagh, new delhi',
#   'city': 'delhi',
#   'code': 'dl',
#   'pincode': '201001',
#   'notes': 'Packaging repaired'},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661433822932,
#   'data': '{temp :  37C}'},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661451883380,
#   'data': '{temp :  37C}'},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661452048050,
#   'data': '{temp :  37C}'},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661452075083,
#   'data': '{temp :  37C}'},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661452104455,
#   'data': '{temp :  37C}'},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661459839764,
#   'data': '{temp :  37C}'},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661461561660,
#   'data': '{temp :  37C}'},
#  {'Event': 'Hardware Data', 'timestamp': 1661482463740, 'data': 1548},
#  {'Event': 'Hardware Data', 'timestamp': 1661487571056, 'data': 'hello'},
#  {'Event': 'Hardware Data', 'timestamp': 1661487573045, 'data': 'hello'},
#  {'Event': 'Hardware Data', 'timestamp': 1661487582829, 'data': 'hello'},
#  {'Event': 'Hardware Data', 'timestamp': 1661487585240, 'data': 'hello'},
#  {'Event': 'Hardware Data', 'timestamp': 1661488518905, 'data': 'h'},
#  {'Event': 'Hardware Data', 'timestamp': 1661488541773, 'data': 'h'},
#  {'Event': 'Hardware Data', 'timestamp': 1661488564276, 'data': 'h'},
#  {'Event': 'Hardware Data', 'timestamp': 1661488586556, 'data': 'h'},
#  {'Event': 'Hardware Data', 'timestamp': 1661488613753, 'data': 'h'},
#  {'Event': 'Hardware Data', 'timestamp': 1661488636001, 'data': 'h'},
#  {'Event': 'Hardware Data', 'timestamp': 1661488658055, 'data': 'h'},
#  {'Event': 'Hardware Data', 'timestamp': 1661488680335, 'data': 'h'},
#  {'Event': 'Hardware Data', 'timestamp': 1661488702556, 'data': 'h'},
#  {'Event': 'Hardware Data', 'timestamp': 1661488724903, 'data': 'h'},
#  {'Event': 'Hardware Data', 'timestamp': 1661488747953, 'data': 'h'},
#  {'Event': 'Hardware Data', 'timestamp': 1661488770354, 'data': 'h'},
#  {'Event': 'Hardware Data', 'timestamp': 1661488789540, 'data': 1548},
#  {'Event': 'Hardware Data', 'timestamp': 1661488830711, 'data': 'h'},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661488870443,
#   'data': {'timestamp': '26/08/2022 05:41:09',
#    'gps': '9.57 , 77.67',
#    'temperature': 26,
#    'humidity': 58}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661495107717,
#   'data': {'timestamp': '26/08/2022 07:25:05',
#    'gps': '9.57 , 77.67',
#    'temperature': 24,
#    'humidity': 56}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661495115012,
#   'data': {'timestamp': '26/08/2022 07:25:13',
#    'gps': '9.57 , 77.67',
#    'temperature': 24,
#    'humidity': 56}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661505462588,
#   'data': {'timestamp': '26/08/2022 10:17:27',
#    'temperature': 25,
#    'humidity': 52,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661505465805,
#   'data': {'timestamp': '26/08/2022 10:17:43',
#    'temperature': 25,
#    'humidity': 52,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661505510182,
#   'data': {'timestamp': '26/08/2022 10:18:28',
#    'temperature': 25,
#    'humidity': 52,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661505512236,
#   'data': {'timestamp': '26/08/2022 10:18:31',
#    'temperature': 25,
#    'humidity': 53,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661505715582,
#   'data': {'timestamp': '26/08/2022 10:21:51',
#    'temperature': 25,
#    'humidity': 53,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661505737919,
#   'data': {'timestamp': '26/08/2022 10:22:16',
#    'temperature': 25,
#    'humidity': 53,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661505744344,
#   'data': {'timestamp': '26/08/2022 10:22:22',
#    'temperature': 25,
#    'humidity': 53,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661508262460,
#   'data': {'timestamp': '26/08/2022 11:04:19',
#    'temperature': 25,
#    'humidity': 54,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661508285760,
#   'data': {'timestamp': '26/08/2022 11:04:43',
#    'temperature': 25,
#    'humidity': 54,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661508306214,
#   'data': {'timestamp': '26/08/2022 11:05:03',
#    'temperature': 25,
#    'humidity': 54,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661508331031,
#   'data': {'timestamp': '26/08/2022 11:05:29',
#    'temperature': 25,
#    'humidity': 54,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661508353422,
#   'data': {'timestamp': '26/08/2022 11:05:52',
#    'temperature': 25,
#    'humidity': 54,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661508379289,
#   'data': {'timestamp': '26/08/2022 11:06:16',
#    'temperature': 25,
#    'humidity': 54,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661508407365,
#   'data': {'timestamp': '26/08/2022 11:06:45',
#    'temperature': 25,
#    'humidity': 54,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661508430695,
#   'data': {'timestamp': '26/08/2022 11:07:08',
#    'temperature': 25,
#    'humidity': 54,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661510402640,
#   'data': {'timestamp': '26/08/2022 11:40:00',
#    'temperature': 24,
#    'humidity': 51,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661510425956,
#   'data': {'timestamp': '26/08/2022 11:40:23',
#    'temperature': 24,
#    'humidity': 51,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661510428550,
#   'data': {'timestamp': '26/08/2022 11:40:26',
#    'temperature': 24,
#    'humidity': 51,
#    'gps': '9.57 , 77.67'}},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661533676046,
#   'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661534013761,
#   'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661534023181,
#   'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661534064851,
#   'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661534067319,
#   'data': '[ {timestamp : 26/08/2022 18:05:25, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:30, temperature: 37, humidity:54.0}, {timestamp : 26/08/2022 18:05:35, temperature: 37, humidity:54.0} ]'},
#  {'Event': 'Hardware Data',
#   'timestamp': 1661535294710,
#   'data': [{'timestamp': '26/08/2022 18:34:17',
#     'temperature': 24,
#     'humidity': 54,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': '26/08/2022 18:34:23',
#     'temperature': 25,
#     'humidity': 54,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': '26/08/2022 18:34:31',
#     'temperature': 25,
#     'humidity': 54,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': '26/08/2022 18:34:36',
#     'temperature': 25,
#     'humidity': 54,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': '26/08/2022 18:34:42',
#     'temperature': 25,
#     'humidity': 54,
#     'gps': '9.57 , 77.67'},
#    {'timestamp': '26/08/2022 18:34:47',
#     'temperature': 25,
#     'humidity': 54,
#     'gps': '9.57 , 77.67'}]},
#  {'Event': 'Departed delhi, dl',
#   'timestamp': 1661537458081,
#   'company_name': 'gatiman express',
#   'address': 'karol bagh, new delhi',
#   'city': 'delhi',
#   'code': 'dl',
#   'pincode': '201001',
#   'notes': 'None'},
#  {'Event': 'Departed delhi, dl',
#   'timestamp': 1661537496465,
#   'company_name': 'gatiman express',
#   'address': 'karol bagh, new delhi',
#   'city': 'delhi',
#   'code': 'dl',
#   'pincode': '201001',
#   'notes': 'None'},
#  {'Event': 'Departed delhi, dl',
#   'timestamp': 1661543914296,
#   'company_name': 'gatiman express',
#   'address': 'karol bagh, new delhi',
#   'city': 'delhi',
#   'code': 'dl',
#   'pincode': '201001',
#   'notes': 'None'},
#  {'Event': 'Departed delhi, dl',
#   'timestamp': 1661568646589,
#   'company_name': 'gatiman express',
#   'address': 'karol bagh, new delhi',
#   'city': 'delhi',
#   'code': 'dl',
#   'pincode': '201001',
#   'notes': 'None'},
#  {'Event': 'Departed delhi, dl',
#   'timestamp': 1661568663061,
#   'company_name': 'gatiman express',
#   'address': 'karol bagh, new delhi',
#   'city': 'delhi',
#   'code': 'dl',
#   'pincode': '201001',
#   'notes': 'None'},
#  {'Event': 'Departed delhi, dl',
#   'timestamp': 1661572888724,
#   'company_name': 'gatiman express',
#   'address': 'karol bagh, new delhi',
#   'city': 'delhi',
#   'code': 'dl',
#   'pincode': '201001',
#   'notes': 'None'},
#  {'Event': 'Departed delhi, dl',
#   'timestamp': 1661573547458,
#   'company_name': 'gatiman express',
#   'address': 'karol bagh, new delhi',
#   'city': 'delhi',
#   'code': 'dl',
#   'pincode': '201001',
#   'notes': 'None'}]

# %%
a[0].keys()
# Out:
# dict_keys(['Event', 'timestamp', 'name', 'description', 'producer', 'registered_at_pincode', 'weight'])

# %%
for i in range(a):
    if a[i]

# %%
temp = []
humidity = []
timestamp = []
for i in range(len(a)):
    if 'data' in a[i].keys():
        if type(a[i]['data']) == dict:
            humidity.append(a[i]['data']['humidity'])
            temp.append(a[i]['data']['temperature'])
            timestamp.append(a[i]['data']['timestamp'])

# %%
temp
# Out:
# [26,
#  24,
#  24,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  24,
#  24,
#  24]

# %%
humidity
# Out:
# [58,
#  56,
#  56,
#  52,
#  52,
#  52,
#  53,
#  53,
#  53,
#  53,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  51,
#  51,
#  51]

# %%
timestamp
# Out:
# ['26/08/2022 05:41:09',
#  '26/08/2022 07:25:05',
#  '26/08/2022 07:25:13',
#  '26/08/2022 10:17:27',
#  '26/08/2022 10:17:43',
#  '26/08/2022 10:18:28',
#  '26/08/2022 10:18:31',
#  '26/08/2022 10:21:51',
#  '26/08/2022 10:22:16',
#  '26/08/2022 10:22:22',
#  '26/08/2022 11:04:19',
#  '26/08/2022 11:04:43',
#  '26/08/2022 11:05:03',
#  '26/08/2022 11:05:29',
#  '26/08/2022 11:05:52',
#  '26/08/2022 11:06:16',
#  '26/08/2022 11:06:45',
#  '26/08/2022 11:07:08',
#  '26/08/2022 11:40:00',
#  '26/08/2022 11:40:23',
#  '26/08/2022 11:40:26']

# %%
import matplotlib.pyplot as plt

# %%
type(timestamp[0])
# Out:
# str

# %%
import pandas as pd
import matplotlib.pyplot as plt

date_time = timestamp
date_time = pd.to_datetime(date_time)
data = temp

DF = pd.DataFrame()
DF['value'] = data
DF = DF.set_index(date_time)
plt.plot(DF)
plt.gcf().autofmt_xdate()
plt.show()

# %%
lt = 24.00
ut = 26.00
count = 0
for i in temp:
    if i>=lt and i<=ut:
        count+=1
scoretemp = count/len(temp)

# %%
scoretemp*100
# Out:
# 100.0

# %%
lt = 24.00
ut = 26.00
count = 0
for i in humidity:
    if i>=lt and i<=ut:
        count+=1
scorehum = count/len(humidity)
